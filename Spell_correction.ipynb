# %% [markdown]
# <a href="https://colab.research.google.com/github/Purvajavenkatesh04/NLP_RECORD/blob/main/Spell_correction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from textblob import TextBlob

# Input text with spelling mistakes
text = "I havv a speling eror in this sentense"

# Create a TextBlob object
blob = TextBlob(text)

# Correct the spelling
corrected_text = blob.correct()

# Output
print("Corrected text:")
print([str(corrected_text)])
# Out:
# Corrected text:
# ['I have a spelling error in this sentence']
