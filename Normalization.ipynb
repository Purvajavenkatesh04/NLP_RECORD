# %% [markdown]
# <a href="https://colab.research.google.com/github/Purvajavenkatesh04/NLP_RECORD/blob/main/Normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import string
from nltk.tokenize import word_tokenize

# Download tokenizer data (only needed once)
nltk.download('punkt')

# Input text
text = "NLTK is GREAT!!   It helps in   Natural Language Processing..."

# Step 1: Convert to lowercase
text = text.lower()

# Step 2: Remove punctuation
text = text.translate(str.maketrans('', '', string.punctuation))

# Step 3: Tokenize the cleaned text
tokens = word_tokenize(text)

# Step 4: Remove extra spaces (handled automatically in tokenization)
# Final normalized output
print("Normalized Output:")
print([token for token in tokens])
# Out:
# Normalized Output:
# ['nltk', 'is', 'great', 'it', 'helps', 'in', 'natural', 'language', 'processing']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
