# %% [markdown]
# <a href="https://colab.research.google.com/github/Purvajavenkatesh04/NLP_RECORD/blob/main/Lemmatization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
text = "The cat looks cute"
doc = nlp(text)
lemmatized = [token.lemma_ for token in doc]
print(lemmatized)
# Out:
# ['the', 'cat', 'look', 'cute']
